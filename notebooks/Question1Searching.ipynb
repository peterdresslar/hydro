# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ## Question 1: How much data
#
# Search 1: A simple, broad search of literature regarding hydrophobicity in plant leaves.
#
# `Hydrophobicity AND plant leaves`

# %%
import os
import requests
import pandas as pd
import random
import pathlib
import re
import time
from PyPDF2 import PdfReader
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")


query_string = 'Hydrophobi*+"plant+leaves"'
encoded_query = query_string  # → Hydrophobicity+AND+%22plant+leaves%22

RESOURCE_URL = "https://api.elsevier.com/"
SEARCH_URL = f"{RESOURCE_URL}/content/search/scopus"
ARTICLE_URL = f"{RESOURCE_URL}/content/article"

headers = {
    "X-ELS-APIKey": api_key,
    "Accept": "application/json",
}
params_counting_only = {
    "query": encoded_query,
    "count": 0,
}

# Hit count
r_count = requests.get(SEARCH_URL, headers=headers, params=params_counting_only)
r_count.raise_for_status()

total_hits = int(r_count.json()["search-results"]["opensearch:totalResults"])

print(f"Total hits for {encoded_query}: {total_hits}")

LIMIT = 25

params = {
    "query": encoded_query,
    "count": LIMIT,
}

resp = requests.get(SEARCH_URL, headers=headers, params=params)

if resp.status_code != 200:
    raise RuntimeError(f"Scopus API error {resp.status_code}: {resp.text}")

entries = resp.json().get("search-results", {}).get("entry", [])
records = [
    {
        "Title": e.get("dc:title"),
        "Authors": e.get("dc:creator"),
        "Year": e.get("prism:coverDate", "").split("-")[0],
        "URL": e.get("prism:url"),
    }
    for e in entries
]
df = pd.DataFrame(records)
print(f"Returned {len(df)} documents")
display(df)  # in a notebook this renders a nice HTML table
# df.to_csv("scopus_results.csv", index=False)   # optional persist
# Out:
# Total hits for Hydrophobi*+"plant+leaves": 6219
# Returned 25 documents
#                                                 Title              Authors  \
# 0   The suberin transporter StABCG1 is required fo...  Benatto Perino E.H.
# 1   Combining plant extracts and hot water treatme...             Worku S.
# 2   Sustainable pest management using plant second...             Zhang X.
# 3   Plant Cell Wall-Like Soft Materials: Micro- an...           Koshani R.
# 4   Anti-proliferative and photodynamic activities...       Olofinsan K.A.
# 5   Optimization of betulinic and ursolic acids an...           Demiray H.
# 6   De novo assembly of the mitochondrial genome o...              Zhou G.
# 7   Discovery of potent anti-toxoplasmosis drugs f...      Mohammed M.M.D.
# 8   Withania coagulans-mediated green synthesis of...              Khan A.
# 9   The nano-paradox: addressing nanotoxicity for ...          Rajpal V.R.
# 10  Understanding ultrafast free-rising bubble cap...                Hu Y.
# 11  Chemical profile, virtual screening, and virul...        Hassan W.H.B.
# 12  In vitro and in silico pharmacological effects...        Alaboudi K.A.
# 13  Review on the need for inventories and managem...             Weber R.
# 14  A supramolecular bactericidal material for pre...              Yang J.
# 15  Innovative applications of SERS in precision m...              Chen B.
# 16  Research on underwater air layer retention and...               Sun H.
# 17  Insights into structure-antioxidant activity r...             Xiang Y.
# 18  High-Performance green fluorescent carbon Dots...              Wang Y.
# 19  A general strategy to enhance surface hydropho...              Chen X.
# 20  Enhancing fog harvesting efficiency with a mul...               Luo J.
# 21  Polylactic acid microplastics and earthworms d...              Chen C.
# 22  Unveiling the impact of soil depth on degradat...               Xie Y.
# 23  Understanding the response mechanisms of C4 an...                Xu X.
# 24  Low-dose natural clay Kaolin promotes the grow...               Sun S.
#
#     Year                                                URL
# 0   2025  https://api.elsevier.com/content/abstract/scop...
# 1   2025  https://api.elsevier.com/content/abstract/scop...
# 2   2025  https://api.elsevier.com/content/abstract/scop...
# 3   2025  https://api.elsevier.com/content/abstract/scop...
# 4   2025  https://api.elsevier.com/content/abstract/scop...
# 5   2025  https://api.elsevier.com/content/abstract/scop...
# 6   2025  https://api.elsevier.com/content/abstract/scop...
# 7   2025  https://api.elsevier.com/content/abstract/scop...
# 8   2025  https://api.elsevier.com/content/abstract/scop...
# 9   2025  https://api.elsevier.com/content/abstract/scop...
# 10  2025  https://api.elsevier.com/content/abstract/scop...
# 11  2025  https://api.elsevier.com/content/abstract/scop...
# 12  2025  https://api.elsevier.com/content/abstract/scop...
# 13  2025  https://api.elsevier.com/content/abstract/scop...
# 14  2025  https://api.elsevier.com/content/abstract/scop...
# 15  2025  https://api.elsevier.com/content/abstract/scop...
# 16  2025  https://api.elsevier.com/content/abstract/scop...
# 17  2025  https://api.elsevier.com/content/abstract/scop...
# 18  2025  https://api.elsevier.com/content/abstract/scop...
# 19  2025  https://api.elsevier.com/content/abstract/scop...
# 20  2025  https://api.elsevier.com/content/abstract/scop...
# 21  2025  https://api.elsevier.com/content/abstract/scop...
# 22  2025  https://api.elsevier.com/content/abstract/scop...
# 23  2025  https://api.elsevier.com/content/abstract/scop...
# 24  2025  https://api.elsevier.com/content/abstract/scop...

# %% [markdown]
# Here we have a good first look at some very coarse-grained results. Let's go in and use random offsets to retrieve 25 random documents.

# %%
from requests.adapters import HTTPAdapter, Retry


# ------------------------------------------------------------------
# Configuration
# ------------------------------------------------------------------
load_dotenv()
API_KEY = os.getenv("API_KEY")  # ← your Elsevier key
EMAIL = os.getenv("EMAIL")  # ← required by Unpaywall
DL_DIR = pathlib.Path("../data/downloads")
DL_DIR.mkdir(exist_ok=True)

TARGET = 25  # how many full-text docs we want
SEARCH_PAGE_SZ = 25  # pull 25 hits per random page
MAX_OFFSET = 5000 - SEARCH_PAGE_SZ  # Scopus hard cap with start=

hdrs_core = {"X-ELS-APIKey": API_KEY}
hdrs_xml = {**hdrs_core, "Accept": "text/xml"}
hdrs_pdf = {**hdrs_core, "Accept": "application/pdf"}


def log(msg):
    print(time.strftime("%H:%M:%S"), msg)


# ------------------------------------------------------------------
# Helper functions
# ------------------------------------------------------------------
def extract_data(entry: dict) -> dict:
    """Return data (if present) from a search entry."""
    eid = entry.get("eid") or entry.get("dc:identifier", "").split(":")[-1]
    return {
        "eid": eid,
        "doi": entry.get("prism:doi"),
        "pii": entry.get("pii"),
        "title": entry.get("dc:title", "")[:80] + "…",
        "authors": entry.get("dc:creator"),
        "journal": entry.get("prism:publicationName"),
        "year": entry.get("prism:coverDate", "").split("-")[0],
    }


if PdfReader:
    def is_multi_page(path: pathlib.Path) -> bool:    # ← NEW
        try:
            return len(PdfReader(str(path)).pages) > 1
        except Exception:
            return False
else:                                                 # ← NEW fallback
    def is_multi_page(path: pathlib.Path) -> bool:    # ← NEW
        return path.stat().st_size > 400_000          # ~= 390 KiB


# ------------------------------------------------------------------
#  robust Session  (re-use everywhere)
# ------------------------------------------------------------------
S = requests.Session()
retries = Retry(
    total=4,  # max 4 attempts
    backoff_factor=0.4,  # 0.4, 0.8, 1.6, 3.2 s
    status_forcelist=[502, 503, 504, 429],
    allowed_methods=["GET"],
)
S.mount("https://", HTTPAdapter(max_retries=retries))
S.headers.update({"X-ELS-APIKey": API_KEY})  # applied to every request

# dedicated headers for full-text
HDR_XML = {"Accept": "text/xml"}
HDR_PDF = {"Accept": "application/pdf"}

DELAY = 0.3  # polite pause after every outgoing request


# ------------------------------------------------------------------
def save_article(url: str, path: pathlib.Path, hdr: dict) -> bool:
    """Try to download url → path (with retries); return True if saved."""
    try:
        r = S.get(url, headers=hdr, stream=True, timeout=30, allow_redirects=True)
        time.sleep(DELAY)
        if r.status_code == 200:
            with path.open("wb") as fh:
                for chunk in r.iter_content(8192):
                    fh.write(chunk)
            return True
    except requests.RequestException as exc:
        log(f"      …download error ({exc.__class__.__name__}) – skipped")
    return False


# ------------------------------------------------------------------
FULL_TEXT_MARKER = re.compile(rb"<ce:section\b", re.I)

# ----------------------------------------------------------------------
# Article-Retrieval first, generic fall-backs after that
# ----------------------------------------------------------------------
FULL_TEXT_MARKER = re.compile(rb"<ce:section\b", re.I)   # body present?

def try_sciencedirect(ids):
    """
    Return pathlib.Path to saved full-article payload or None.

    1. Article-Retrieval PDF  (view=ENTITLED)                 ← publisher PDF
    2. Article-Retrieval PDF  (view=ENTITLED&amsRedirect=true)← author manuscript
    3. Article-Retrieval XML (view=FULL)
    4. legacy publisher-PDF fall-back (unchanged)
    """
    for key in ("doi", "pii", "eid"):          # order of preference
        value = ids.get(key)
        if not value:
            continue

        # 1) publisher PDF
        log(f"API-ENTITLED → {key}:{value}")
        pdf_url  = f"{ARTICLE_URL}/{key}/{value}?view=ENTITLED&httpAccept=application/pdf"
        pdf_path = DL_DIR / f"{value.replace('/', '_')}.pdf"
        if save_article(pdf_url, pdf_path, HDR_PDF):
            if pdf_path.stat().st_size > 100_000:
                if is_multi_page(pdf_path):
                    return pdf_path
            pdf_path.unlink(missing_ok=True)

        # 2) author-manuscript PDF
        log(f"API-AMS       → {key}:{value}")
        ams_url  = f"{ARTICLE_URL}/{key}/{value}?view=ENTITLED&httpAccept=application/pdf&amsRedirect=true"
        ams_path = DL_DIR / f"{value.replace('/', '_')}_AM.pdf"
        if save_article(ams_url, ams_path, HDR_PDF):
            if ams_path.stat().st_size > 100_000:
                if is_multi_page(ams_path):
                    return ams_path
            ams_path.unlink(missing_ok=True)

        # 3) FULL-view XML
        log(f"API-FULL-XML  → {key}:{value}")
        xml_url  = f"{ARTICLE_URL}/{key}/{value}?view=FULL"
        xml_path = DL_DIR / f"{value.replace('/', '_')}.xml"
        if save_article(xml_url, xml_path, HDR_XML):
            with xml_path.open("rb") as fh:
                if FULL_TEXT_MARKER.search(fh.read(8192)):
                    return xml_path
            xml_path.unlink(missing_ok=True)

    # 4) legacy fall-back (publisher PDF via generic endpoint)
    doi = ids.get("doi")
    if not doi:
        return None
    legacy_path = DL_DIR / f"{doi.replace('/', '_')}.pdf"
    log(f"LEGACY        → doi:{doi}")
    if save_article(f"{ARTICLE_URL}/doi/{doi}", legacy_path, HDR_PDF):
        if legacy_path.stat().st_size > 100_000:
            if is_multi_page(legacy_path):
                return legacy_path
        legacy_path.unlink(missing_ok=True)
    return None
    

# ------------------------------------------------------------------
def try_unpaywall(doi):
    if not doi:
        return None
    meta = S.get(
        f"https://api.unpaywall.org/v2/{doi}", params={"email": EMAIL}, timeout=15
    )
    time.sleep(DELAY)
    pdf = (meta.json().get("best_oa_location") or {}).get("url_for_pdf")
    if pdf:
        fname = DL_DIR / f"{doi.replace('/', '_')}_OA.pdf"
        if fname.exists() or save_article(pdf, fname, hdr={}):
            return fname
    return None


# ------------------------------------------------------------------

# ------------------------------------------------------------------
# Main sampling loop
# ------------------------------------------------------------------
fulltext_records, seen_eids = [], set()
upper_bound = min(
    MAX_OFFSET,
    int(r_count.json()["search-results"]["opensearch:totalResults"]) - SEARCH_PAGE_SZ,
)

while len(fulltext_records) < TARGET:
    start = random.randint(0, upper_bound)
    params = {"query": encoded_query, "count": SEARCH_PAGE_SZ, "start": start}
    page = requests.get(SEARCH_URL, headers=hdrs_core, params=params)
    page.raise_for_status()
    entries = page.json()["search-results"].get("entry", [])
    log(f"Scanned page @offset {start:,}")

    for e in entries:
        ids = extract_data(e)
        if ids["eid"] in seen_eids:  # avoid duplicates
            continue

        # ---------- attempt full-text ----------
        path = try_sciencedirect(ids)
        if not path:
            path = try_unpaywall(ids["doi"])
        if path:
            ids["full_text"] = str(path)
            fulltext_records.append(ids)
        else:
            log("  ✖ no full text")

        if len(fulltext_records) == TARGET:
            break

df_full = pd.DataFrame(fulltext_records)
cols = ["title", "journal", "authors", "year", "doi", "full_text"]
display(df_full[cols])
df_full.to_csv("../data/random25_fulltext.csv", index=False)
log("Completed – 25 full-text documents obtained.")
# Out:
# 12:14:08 Scanned page @offset 3,599
# 12:14:08 API-ENTITLED → doi:10.1093/jpe/rtx037
# 12:14:09 API-AMS       → doi:10.1093/jpe/rtx037
# 12:14:10 API-FULL-XML  → doi:10.1093/jpe/rtx037
# 12:14:11 API-ENTITLED → eid:2-s2.0-85038372433
# 12:14:12 API-AMS       → eid:2-s2.0-85038372433
# 12:14:12 API-FULL-XML  → eid:2-s2.0-85038372433
# 12:14:13 LEGACY        → doi:10.1093/jpe/rtx037
# 12:14:15   ✖ no full text
# 12:14:15 API-ENTITLED → doi:10.1016/j.surfcoat.2017.11.053
# 12:14:16 API-AMS       → doi:10.1016/j.surfcoat.2017.11.053
# 12:14:17 API-FULL-XML  → doi:10.1016/j.surfcoat.2017.11.053
# 12:14:17 API-ENTITLED → pii:S025789721731201X
# 12:14:18 API-AMS       → pii:S025789721731201X
# 12:14:19 API-FULL-XML  → pii:S025789721731201X
# 12:14:20 API-ENTITLED → eid:2-s2.0-85036527773
# 12:14:54 API-ENTITLED → pii:S0882401017306940
# 12:14:54 API-AMS       → pii:S0882401017306940
# 12:14:55 API-FULL-XML  → pii:S0882401017306940
# 12:14:56 API-ENTITLED → eid:2-s2.0-85049512180
# 12:14:57 API-AMS       → eid:2-s2.0-85049512180
# 12:14:57 API-FULL-XML  → eid:2-s2.0-85049512180
# 12:14:58 LEGACY        → doi:10.1016/j.micpath.2018.03.041
# 12:14:59   ✖ no full text
# 12:14:59 API-ENTITLED → doi:10.4103/2221-1691.233005
# 12:15:00 API-AMS       → doi:10.4103/2221-1691.233005
# 12:15:02 API-FULL-XML  → doi:10.4103/2221-1691.233005
# 12:15:02 API-ENTITLED → eid:2-s2.0-85047506846
# 12:15:03 API-AMS       → eid:2-s2.0-85047506846
# 12:15:04 API-FULL-XML  → eid:2-s2.0-85047506846
# 12:15:04 LEGACY        → doi:10.4103/2221-1691.233005
# 12:15:05   ✖ no full text
# 12:15:05 API-ENTITLED → doi:10.1093/pcp/pcy035
# 12:15:06 API-AMS       → doi:10.1093/pcp/pcy035
# 12:15:06 API-FULL-XML  → doi:10.1093/pcp/pcy035
# 12:15:07 API-ENTITLED → eid:2-s2.0-85047101544
# 12:15:08 API-AMS       → eid:2-s2.0-85047101544
# 12:15:08 API-FULL-XML  → eid:2-s2.0-85047101544
# 12:15:09 LEGACY        → doi:10.1093/pcp/pcy035
# 12:15:10   ✖ no full text
# 12:15:10 API-ENTITLED → doi:10.1093/pcp/pcy033
# 12:15:11 API-AMS       → doi:10.1093/pcp/pcy033
# 12:15:12 API-FULL-XML  → doi:10.1093/pcp/pcy033
# 12:15:12 API-ENTITLED → eid:2-s2.0-85047074499
# 12:15:13 API-AMS       → eid:2-s2.0-85047074499
# 12:15:13 API-FULL-XML  → eid:2-s2.0-85047074499
# 12:15:14 LEGACY        → doi:10.1093/pcp/pcy033
# 12:15:15   ✖ no full text
# 12:15:15 API-ENTITLED → doi:10.1371/journal.pone.0196667
# 12:15:16 API-AMS       → doi:10.1371/journal.pone.0196667
# 12:15:17 API-FULL-XML  → doi:10.1371/journal.pone.0196667
# 12:15:17 API-ENTITLED → eid:2-s2.0-85046939180
# 12:15:18 API-AMS       → eid:2-s2.0-85046939180
# 12:15:18 API-FULL-XML  → eid:2-s2.0-85046939180
# 12:15:19 LEGACY        → doi:10.1371/journal.pone.0196667
# 12:15:22 API-ENTITLED → doi:10.1111/1462-2920.14112
# 12:15:23 API-AMS       → doi:10.1111/1462-2920.14112
# 12:15:24 API-FULL-XML  → doi:10.1111/1462-2920.14112
# 12:15:24 API-ENTITLED → eid:2-s2.0-85045833905
# 12:15:25 API-AMS       → eid:2-s2.0-85045833905
# 12:15:26 API-FULL-XML  → eid:2-s2.0-85045833905
# 12:15:26 LEGACY        → doi:10.1111/1462-2920.14112
# 12:15:27   ✖ no full text
# 12:15:27 API-ENTITLED → doi:10.1007/s00044-018-2157-1
# 12:15:28 API-AMS       → doi:10.1007/s00044-018-2157-1
# 12:15:29 API-FULL-XML  → doi:10.1007/s00044-018-2157-1
# 12:15:29 API-ENTITLED → eid:2-s2.0-85044970741
# 12:15:30 API-AMS       → eid:2-s2.0-85044970741
# 12:15:31 API-FULL-XML  → eid:2-s2.0-85044970741
# 12:15:31 LEGACY        → doi:10.1007/s00044-018-2157-1
# 12:15:32   ✖ no full text
# 12:15:32 API-ENTITLED → doi:10.1002/etc.4081
# 12:15:33 API-AMS       → doi:10.1002/etc.4081
# 12:15:33 API-FULL-XML  → doi:10.1002/etc.4081
# 12:15:34 API-ENTITLED → eid:2-s2.0-85044203674
# 12:15:35 API-AMS       → eid:2-s2.0-85044203674
# 12:15:35 API-FULL-XML  → eid:2-s2.0-85044203674
# 12:15:36 LEGACY        → doi:10.1002/etc.4081
# 12:15:37   ✖ no full text
# 12:15:37 API-ENTITLED → doi:10.1002/elps.201700482
# 12:15:38 API-AMS       → doi:10.1002/elps.201700482
# 12:15:38 API-FULL-XML  → doi:10.1002/elps.201700482
# 12:15:39 API-ENTITLED → eid:2-s2.0-85043391473
# 12:15:39 API-AMS       → eid:2-s2.0-85043391473
# 12:15:40 API-FULL-XML  → eid:2-s2.0-85043391473
# 12:15:41 LEGACY        → doi:10.1002/elps.201700482
# 12:15:42   ✖ no full text
# 12:15:42 API-ENTITLED → doi:10.1016/j.psep.2018.02.010
# 12:15:44 API-AMS       → doi:10.1016/j.psep.2018.02.010
# 12:15:45 API-FULL-XML  → doi:10.1016/j.psep.2018.02.010
# 12:15:46 API-ENTITLED → pii:S0957582018300429
# 12:15:47 API-AMS       → pii:S0957582018300429
# 12:15:48 API-FULL-XML  → pii:S0957582018300429
# 12:15:49 API-ENTITLED → eid:2-s2.0-85042649540
# 12:15:49 API-AMS       → eid:2-s2.0-85042649540
# 12:15:50 API-FULL-XML  → eid:2-s2.0-85042649540
# 12:15:50 LEGACY        → doi:10.1016/j.psep.2018.02.010
# 12:15:52   ✖ no full text
# 12:15:52 API-ENTITLED → doi:10.1016/j.biopha.2018.02.074
# 12:15:53 API-AMS       → doi:10.1016/j.biopha.2018.02.074
# 12:15:54 API-FULL-XML  → doi:10.1016/j.biopha.2018.02.074
# 12:15:54 API-ENTITLED → pii:S075333221830177X
# 12:15:55 API-AMS       → pii:S075333221830177X
# 12:15:56 API-FULL-XML  → pii:S075333221830177X
# 12:15:57 API-ENTITLED → eid:2-s2.0-85042426834
# 12:15:57 API-AMS       → eid:2-s2.0-85042426834
# 12:15:58 API-FULL-XML  → eid:2-s2.0-85042426834
# 12:15:58 LEGACY        → doi:10.1016/j.biopha.2018.02.074
# 12:16:00   ✖ no full text
# 12:16:00 API-ENTITLED → doi:10.1093/jxb/ery085
# 12:16:00 API-AMS       → doi:10.1093/jxb/ery085
# 12:16:01 API-FULL-XML  → doi:10.1093/jxb/ery085
# 12:16:02 API-ENTITLED → eid:2-s2.0-85046290047
# 12:16:02 API-AMS       → eid:2-s2.0-85046290047
# 12:16:03 API-FULL-XML  → eid:2-s2.0-85046290047
# 12:16:03 LEGACY        → doi:10.1093/jxb/ery085
# 12:16:05   ✖ no full text
# 12:16:05 API-ENTITLED → doi:10.1515/ntrev-2017-0199
# 12:16:06 API-AMS       → doi:10.1515/ntrev-2017-0199
# 12:16:06 API-FULL-XML  → doi:10.1515/ntrev-2017-0199
# 12:16:07 API-ENTITLED → eid:2-s2.0-85040973984
# 12:16:08 API-AMS       → eid:2-s2.0-85040973984
# 12:16:08 API-FULL-XML  → eid:2-s2.0-85040973984
# 12:16:09 LEGACY        → doi:10.1515/ntrev-2017-0199
# 12:16:10   ✖ no full text
# 12:16:10 API-ENTITLED → doi:10.3389/fpls.2018.00494
# 12:16:11 API-AMS       → doi:10.3389/fpls.2018.00494
# 12:16:11 API-FULL-XML  → doi:10.3389/fpls.2018.00494
# 12:16:12 API-ENTITLED → eid:2-s2.0-85046888342
# 12:16:13 API-AMS       → eid:2-s2.0-85046888342
# 12:16:13 API-FULL-XML  → eid:2-s2.0-85046888342
# 12:16:14 LEGACY        → doi:10.3389/fpls.2018.00494
# 12:16:18 API-ENTITLED → doi:10.1098/rsos.172132
# 12:16:19 API-AMS       → doi:10.1098/rsos.172132
# 12:16:20 API-FULL-XML  → doi:10.1098/rsos.172132
# 12:16:20 API-ENTITLED → eid:2-s2.0-85045753242
# 12:16:21 API-AMS       → eid:2-s2.0-85045753242
# 12:16:21 API-FULL-XML  → eid:2-s2.0-85045753242
# 12:16:22 LEGACY        → doi:10.1098/rsos.172132
# 12:16:23   ✖ no full text
# 12:16:23 API-ENTITLED → doi:10.1080/15226514.2017.1365344
# 12:16:24 API-AMS       → doi:10.1080/15226514.2017.1365344
# 12:16:25 API-FULL-XML  → doi:10.1080/15226514.2017.1365344
# 12:16:25 API-ENTITLED → eid:2-s2.0-85044945047
# 12:16:26 API-AMS       → eid:2-s2.0-85044945047
# 12:16:26 API-FULL-XML  → eid:2-s2.0-85044945047
# 12:16:27 LEGACY        → doi:10.1080/15226514.2017.1365344
# 12:16:28   ✖ no full text
# 12:16:28 API-ENTITLED → doi:10.2147/IJN.S157541
# 12:16:29 API-AMS       → doi:10.2147/IJN.S157541
# 12:16:29 API-FULL-XML  → doi:10.2147/IJN.S157541
# 12:16:30 API-ENTITLED → eid:2-s2.0-85045315493
# 12:16:31 API-AMS       → eid:2-s2.0-85045315493
# 12:16:31 API-FULL-XML  → eid:2-s2.0-85045315493
# 12:16:32 LEGACY        → doi:10.2147/IJN.S157541
# 12:16:34 API-ENTITLED → doi:10.1088/2057-1976/aab33a
# 12:16:35 API-AMS       → doi:10.1088/2057-1976/aab33a
# 12:16:36 API-FULL-XML  → doi:10.1088/2057-1976/aab33a
# 12:16:36 API-ENTITLED → eid:2-s2.0-85047237787
# 12:16:37 API-AMS       → eid:2-s2.0-85047237787
# 12:16:37 API-FULL-XML  → eid:2-s2.0-85047237787
# 12:16:38 LEGACY        → doi:10.1088/2057-1976/aab33a
# 12:16:39   ✖ no full text
# 12:16:40 Scanned page @offset 2,455
# 12:16:40 API-ENTITLED → doi:10.1016/j.fct.2021.112284
# 12:16:42 API-ENTITLED → doi:10.1016/j.micron.2021.103073
# 12:16:43 API-AMS       → doi:10.1016/j.micron.2021.103073
# 12:16:43 API-FULL-XML  → doi:10.1016/j.micron.2021.103073
# 12:16:44 API-ENTITLED → pii:S0968432821000640
# 12:16:45 API-AMS       → pii:S0968432821000640
# 12:16:46 API-FULL-XML  → pii:S0968432821000640
# 12:16:46 API-ENTITLED → eid:2-s2.0-85105693013
# 12:16:47 API-AMS       → eid:2-s2.0-85105693013
# 12:16:47 API-FULL-XML  → eid:2-s2.0-85105693013
# 12:16:48 LEGACY        → doi:10.1016/j.micron.2021.103073
# 12:16:49   ✖ no full text
# 12:16:49 API-ENTITLED → doi:10.1002/ps.6407
# 12:16:50 API-AMS       → doi:10.1002/ps.6407
# 12:16:50 API-FULL-XML  → doi:10.1002/ps.6407
# 12:16:51 API-ENTITLED → eid:2-s2.0-85105483050
# 12:16:52 API-AMS       → eid:2-s2.0-85105483050
# 12:16:52 API-FULL-XML  → eid:2-s2.0-85105483050
# 12:16:53 LEGACY        → doi:10.1002/ps.6407
# 12:16:54   ✖ no full text
# 12:16:54 API-ENTITLED → doi:10.1111/1751-7915.13816
# 12:16:54 API-AMS       → doi:10.1111/1751-7915.13816
# 12:16:55 API-FULL-XML  → doi:10.1111/1751-7915.13816
# 12:16:56 API-ENTITLED → eid:2-s2.0-85105223127
# 12:16:56 API-AMS       → eid:2-s2.0-85105223127
# 12:16:57 API-FULL-XML  → eid:2-s2.0-85105223127
# 12:16:57 LEGACY        → doi:10.1111/1751-7915.13816
# 12:17:01 API-ENTITLED → doi:10.1016/j.bpc.2021.106607
# 12:17:02 API-AMS       → doi:10.1016/j.bpc.2021.106607
# 12:17:03 API-FULL-XML  → doi:10.1016/j.bpc.2021.106607
# 12:17:04 API-ENTITLED → pii:S0301462221000892
# 12:17:05 API-AMS       → pii:S0301462221000892
# 12:17:05 API-FULL-XML  → pii:S0301462221000892
# 12:17:06 API-ENTITLED → eid:2-s2.0-85105110426
# 12:17:07 API-AMS       → eid:2-s2.0-85105110426
# 12:17:07 API-FULL-XML  → eid:2-s2.0-85105110426
# 12:17:08 LEGACY        → doi:10.1016/j.bpc.2021.106607
# 12:17:09   ✖ no full text
# 12:17:09 API-ENTITLED → doi:10.1002/ps.6404
# 12:17:10 API-AMS       → doi:10.1002/ps.6404
# 12:17:11 API-FULL-XML  → doi:10.1002/ps.6404
# 12:17:11 API-ENTITLED → eid:2-s2.0-85104813835
# 12:17:12 API-AMS       → eid:2-s2.0-85104813835
# 12:17:12 API-FULL-XML  → eid:2-s2.0-85104813835
# 12:17:13 LEGACY        → doi:10.1002/ps.6404
# 12:17:17 API-ENTITLED → doi:10.1007/s00122-021-03798-y
# 12:17:17 API-AMS       → doi:10.1007/s00122-021-03798-y
# 12:17:18 API-FULL-XML  → doi:10.1007/s00122-021-03798-y
# 12:17:19 API-ENTITLED → eid:2-s2.0-85103218996
# 12:17:19 API-AMS       → eid:2-s2.0-85103218996
# 12:17:20 API-FULL-XML  → eid:2-s2.0-85103218996
# 12:17:20 LEGACY        → doi:10.1007/s00122-021-03798-y
# 12:17:35 API-ENTITLED → doi:10.1111/lam.13471
# 12:19:52   ✖ no full text
# 12:19:52 API-ENTITLED → doi:10.1016/j.rineng.2024.102974
# 12:19:55 API-ENTITLED → doi:10.1186/s12951-024-02849-y
# 12:19:55 API-AMS       → doi:10.1186/s12951-024-02849-y
# 12:19:56 API-FULL-XML  → doi:10.1186/s12951-024-02849-y
# 12:19:57 API-ENTITLED → eid:2-s2.0-85204512103
# 12:19:57 API-AMS       → eid:2-s2.0-85204512103
# 12:19:58 API-FULL-XML  → eid:2-s2.0-85204512103
# 12:19:59 LEGACY        → doi:10.1186/s12951-024-02849-y
# 12:20:00   ✖ no full text
# 12:20:00 API-ENTITLED → doi:10.1016/j.nanoen.2024.110277
# 12:20:02 API-AMS       → doi:10.1016/j.nanoen.2024.110277
# 12:20:03 API-FULL-XML  → doi:10.1016/j.nanoen.2024.110277
# 12:20:04 API-ENTITLED → pii:S2211285524010292
# 12:20:05 API-AMS       → pii:S2211285524010292
# 12:20:06 API-FULL-XML  → pii:S2211285524010292
# 12:20:07 API-ENTITLED → eid:2-s2.0-85204487087
# 12:20:07 API-AMS       → eid:2-s2.0-85204487087
# 12:20:08 API-FULL-XML  → eid:2-s2.0-85204487087
# 12:20:08 LEGACY        → doi:10.1016/j.nanoen.2024.110277
# 12:20:10   ✖ no full text
# 12:20:10 API-ENTITLED → doi:10.1016/j.scitotenv.2024.176247
# 12:20:11 API-AMS       → doi:10.1016/j.scitotenv.2024.176247
# 12:20:12 API-FULL-XML  → doi:10.1016/j.scitotenv.2024.176247
# 12:20:12 API-ENTITLED → pii:S0048969724064039
# 12:20:13 API-AMS       → pii:S0048969724064039
# 12:20:14 API-FULL-XML  → pii:S0048969724064039
# 12:20:15 API-ENTITLED → eid:2-s2.0-85204377781
# 12:20:15 API-AMS       → eid:2-s2.0-85204377781
# 12:20:16 API-FULL-XML  → eid:2-s2.0-85204377781
# 12:20:17 LEGACY        → doi:10.1016/j.scitotenv.2024.176247
# 12:20:18   ✖ no full text
# 12:20:18 API-ENTITLED → doi:10.1016/j.scitotenv.2024.176285
# 12:20:19 API-AMS       → doi:10.1016/j.scitotenv.2024.176285
# 12:20:20 API-FULL-XML  → doi:10.1016/j.scitotenv.2024.176285
# 12:20:21 API-ENTITLED → pii:S0048969724064416
# 12:20:22 API-AMS       → pii:S0048969724064416
# 12:20:23 API-FULL-XML  → pii:S0048969724064416
# 12:20:23 API-ENTITLED → eid:2-s2.0-85204213939
# 12:20:24 API-AMS       → eid:2-s2.0-85204213939
# 12:20:25 API-FULL-XML  → eid:2-s2.0-85204213939
# 12:20:25 LEGACY        → doi:10.1016/j.scitotenv.2024.176285
# 12:20:27   ✖ no full text
# 12:20:27 API-ENTITLED → doi:10.1186/s42483-024-00267-4
# 12:20:27 API-AMS       → doi:10.1186/s42483-024-00267-4
# 12:20:28 API-FULL-XML  → doi:10.1186/s42483-024-00267-4
# 12:20:28 API-ENTITLED → eid:2-s2.0-85203806445
# 12:20:29 API-AMS       → eid:2-s2.0-85203806445
# 12:20:29 API-FULL-XML  → eid:2-s2.0-85203806445
# 12:20:30 LEGACY        → doi:10.1186/s42483-024-00267-4
# 12:20:31   ✖ no full text
# 12:20:31 API-ENTITLED → doi:10.1038/s41598-024-70490-8
# 12:20:32 API-AMS       → doi:10.1038/s41598-024-70490-8
# 12:20:32 API-FULL-XML  → doi:10.1038/s41598-024-70490-8
# 12:20:33 API-ENTITLED → eid:2-s2.0-85203292390
# 12:20:34 API-AMS       → eid:2-s2.0-85203292390
# 12:20:34 API-FULL-XML  → eid:2-s2.0-85203292390
# 12:20:35 LEGACY        → doi:10.1038/s41598-024-70490-8
# 12:20:36   ✖ no full text
# 12:20:36 API-ENTITLED → doi:10.1038/s41598-024-71513-0
# 12:20:36 API-AMS       → doi:10.1038/s41598-024-71513-0
# 12:20:37 API-FULL-XML  → doi:10.1038/s41598-024-71513-0
# 12:20:38 API-ENTITLED → eid:2-s2.0-85203288891
# 12:20:38 API-AMS       → eid:2-s2.0-85203288891
# 12:20:39 API-FULL-XML  → eid:2-s2.0-85203288891
# 12:20:39 LEGACY        → doi:10.1038/s41598-024-71513-0
# 12:20:40   ✖ no full text
# 12:20:40 API-ENTITLED → doi:10.1002/ps.8389
# 12:20:41 API-AMS       → doi:10.1002/ps.8389
# 12:20:42 API-FULL-XML  → doi:10.1002/ps.8389
# 12:20:42 API-ENTITLED → eid:2-s2.0-85203138821
# 12:20:43 API-AMS       → eid:2-s2.0-85203138821
# 12:20:43 API-FULL-XML  → eid:2-s2.0-85203138821
# 12:20:44 LEGACY        → doi:10.1002/ps.8389
# 12:20:45   ✖ no full text
# 12:20:45 API-ENTITLED → doi:10.1186/s11671-024-04090-w
# 12:20:46 API-AMS       → doi:10.1186/s11671-024-04090-w
# 12:20:46 API-FULL-XML  → doi:10.1186/s11671-024-04090-w
# 12:20:47 API-ENTITLED → eid:2-s2.0-85203023588
# 12:20:48 API-AMS       → eid:2-s2.0-85203023588
# 12:20:48 API-FULL-XML  → eid:2-s2.0-85203023588
# 12:20:49 LEGACY        → doi:10.1186/s11671-024-04090-w
# 12:20:50   ✖ no full text
# 12:20:50 API-ENTITLED → doi:10.1016/j.wasman.2024.08.036
# 12:20:51 API-AMS       → doi:10.1016/j.wasman.2024.08.036
# 12:20:52 API-FULL-XML  → doi:10.1016/j.wasman.2024.08.036
# 12:20:53 API-ENTITLED → pii:S0956053X24004707
# 12:20:54 API-AMS       → pii:S0956053X24004707
# 12:20:55 API-FULL-XML  → pii:S0956053X24004707
# 12:20:55 API-ENTITLED → eid:2-s2.0-85203005572
# 12:20:56 API-AMS       → eid:2-s2.0-85203005572
# 12:20:56 API-FULL-XML  → eid:2-s2.0-85203005572
# 12:20:57 LEGACY        → doi:10.1016/j.wasman.2024.08.036
# 12:20:58   ✖ no full text
# 12:20:58 API-ENTITLED → doi:10.1186/s12864-024-10693-5
# 12:20:59 API-AMS       → doi:10.1186/s12864-024-10693-5
# 12:20:59 API-FULL-XML  → doi:10.1186/s12864-024-10693-5
# 12:21:00 API-ENTITLED → eid:2-s2.0-85201940015
# 12:21:01 API-AMS       → eid:2-s2.0-85201940015
# 12:21:01 API-FULL-XML  → eid:2-s2.0-85201940015
# 12:22:31 API-FULL-XML  → eid:2-s2.0-85195976553
# 12:22:32 LEGACY        → doi:10.1186/s40779-024-00541-8
# 12:22:41 Scanned page @offset 2,732
# 12:22:41 API-ENTITLED → doi:10.1016/j.chemosphere.2020.128284
# 12:22:42 API-AMS       → doi:10.1016/j.chemosphere.2020.128284
# 12:22:43 API-FULL-XML  → doi:10.1016/j.chemosphere.2020.128284
# 12:22:43 API-ENTITLED → pii:S0045653520324796
# 12:22:44 API-AMS       → pii:S0045653520324796
# 12:22:45 API-FULL-XML  → pii:S0045653520324796
# 12:22:46 API-ENTITLED → eid:2-s2.0-85090735172
# 12:22:46 API-AMS       → eid:2-s2.0-85090735172
# 12:22:47 API-FULL-XML  → eid:2-s2.0-85090735172
# 12:22:48 LEGACY        → doi:10.1016/j.chemosphere.2020.128284
# 12:22:49   ✖ no full text
# 12:22:49 API-ENTITLED → doi:10.1016/j.apsusc.2020.147728
# 12:22:50 API-AMS       → doi:10.1016/j.apsusc.2020.147728
# 12:22:51 API-FULL-XML  → doi:10.1016/j.apsusc.2020.147728
# 12:22:51 API-ENTITLED → pii:S0169433220324855
# 12:22:52 API-AMS       → pii:S0169433220324855
# 12:22:53 API-FULL-XML  → pii:S0169433220324855
# 12:22:54 API-ENTITLED → eid:2-s2.0-85090551125
# 12:22:54 API-AMS       → eid:2-s2.0-85090551125
# 12:22:55 API-FULL-XML  → eid:2-s2.0-85090551125
# 12:22:56 LEGACY        → doi:10.1016/j.apsusc.2020.147728
# 12:22:57   ✖ no full text
# 12:22:57 API-ENTITLED → doi:10.1007/s00374-020-01505-5
# 12:22:57 API-AMS       → doi:10.1007/s00374-020-01505-5
# 12:22:58 API-FULL-XML  → doi:10.1007/s00374-020-01505-5
# 12:22:59 API-ENTITLED → eid:2-s2.0-85090064957
# 12:22:59 API-AMS       → eid:2-s2.0-85090064957
# 12:23:00 API-FULL-XML  → eid:2-s2.0-85090064957
# 12:23:01 LEGACY        → doi:10.1007/s00374-020-01505-5
# 12:23:05 API-ENTITLED → doi:10.1038/s41579-020-0414-z
# 12:23:06 API-AMS       → doi:10.1038/s41579-020-0414-z
# 12:23:06 API-FULL-XML  → doi:10.1038/s41579-020-0414-z
# 12:23:07 API-ENTITLED → eid:2-s2.0-85089529411
# 12:23:07 API-AMS       → eid:2-s2.0-85089529411
# 12:23:08 API-FULL-XML  → eid:2-s2.0-85089529411
# 12:23:09 LEGACY        → doi:10.1038/s41579-020-0414-z
# 12:23:10   ✖ no full text
# 12:23:10 API-ENTITLED → doi:10.1111/nph.16816
# 12:23:10 API-AMS       → doi:10.1111/nph.16816
# 12:23:11 API-FULL-XML  → doi:10.1111/nph.16816
# 12:23:11 API-ENTITLED → eid:2-s2.0-85089401650
# 12:23:12 API-AMS       → eid:2-s2.0-85089401650
# 12:23:13 API-FULL-XML  → eid:2-s2.0-85089401650
# 12:23:13 LEGACY        → doi:10.1111/nph.16816
# 12:23:15   ✖ no full text
# 12:23:15 API-ENTITLED → doi:10.1080/01694243.2020.1797336
# 12:23:15 API-AMS       → doi:10.1080/01694243.2020.1797336
# 12:24:58 LEGACY        → doi:10.1039/d0nj04551a
# 12:25:00   ✖ no full text
# 12:25:00 API-ENTITLED → doi:10.1039/d0ta09773j
# 12:25:00 API-AMS       → doi:10.1039/d0ta09773j
# 12:25:02 API-FULL-XML  → doi:10.1039/d0ta09773j
# 12:25:02 API-ENTITLED → eid:2-s2.0-85097717339
# 12:25:03 API-AMS       → eid:2-s2.0-85097717339
# 12:25:04 API-FULL-XML  → eid:2-s2.0-85097717339
# 12:25:04 LEGACY        → doi:10.1039/d0ta09773j
# 12:25:06   ✖ no full text
# 12:25:06 API-ENTITLED → doi:10.1016/j.ijfoodmicro.2020.108834
# 12:25:07 API-AMS       → doi:10.1016/j.ijfoodmicro.2020.108834
# 12:25:07 API-FULL-XML  → doi:10.1016/j.ijfoodmicro.2020.108834
# 12:25:08 API-ENTITLED → pii:S0168160520303287
# 12:25:09 API-AMS       → pii:S0168160520303287
# 12:25:10 API-FULL-XML  → pii:S0168160520303287
# 12:25:10 API-ENTITLED → eid:2-s2.0-85089833409
# 12:25:11 API-AMS       → eid:2-s2.0-85089833409
# 12:25:12 API-FULL-XML  → eid:2-s2.0-85089833409
# 12:25:12 LEGACY        → doi:10.1016/j.ijfoodmicro.2020.108834
# 12:25:14   ✖ no full text
# 12:25:15 Scanned page @offset 3,521
# 12:25:15 API-ENTITLED → doi:10.1016/j.jclepro.2018.06.146
# 12:25:16 API-AMS       → doi:10.1016/j.jclepro.2018.06.146
# 12:25:17 API-FULL-XML  → doi:10.1016/j.jclepro.2018.06.146
# 12:25:18 API-ENTITLED → pii:S0959652618317967
# 12:25:18 API-AMS       → pii:S0959652618317967
# 12:25:19 API-FULL-XML  → pii:S0959652618317967
# 12:25:20 API-ENTITLED → eid:2-s2.0-85049300689
# 12:25:20 API-AMS       → eid:2-s2.0-85049300689
# 12:25:21 API-FULL-XML  → eid:2-s2.0-85049300689
# 12:25:22 LEGACY        → doi:10.1016/j.jclepro.2018.06.146
# 12:25:23   ✖ no full text
# 12:25:23 API-ENTITLED → doi:10.1016/j.envexpbot.2018.05.005
# 12:25:24 API-AMS       → doi:10.1016/j.envexpbot.2018.05.005
# 12:25:25 API-FULL-XML  → doi:10.1016/j.envexpbot.2018.05.005
# 12:25:25 API-ENTITLED → pii:S0098847218301862
# 12:25:26 API-AMS       → pii:S0098847218301862
# 12:25:27 API-FULL-XML  → pii:S0098847218301862
# 12:25:28 API-ENTITLED → eid:2-s2.0-85048152660
# 12:25:28 API-AMS       → eid:2-s2.0-85048152660
# 12:25:29 API-FULL-XML  → eid:2-s2.0-85048152660
# 12:25:30 LEGACY        → doi:10.1016/j.envexpbot.2018.05.005
# 12:25:31   ✖ no full text
# 12:25:31 API-ENTITLED → doi:10.1016/j.envpol.2018.05.071
# 12:25:32 API-AMS       → doi:10.1016/j.envpol.2018.05.071
# 12:25:33 API-FULL-XML  → doi:10.1016/j.envpol.2018.05.071
# 12:25:34 API-ENTITLED → pii:S0269749117349023
# 12:25:35 API-AMS       → pii:S0269749117349023
# 12:25:35 API-FULL-XML  → pii:S0269749117349023
# 12:25:36 API-ENTITLED → eid:2-s2.0-85047402805
# 12:25:37 API-AMS       → eid:2-s2.0-85047402805
# 12:25:37 API-FULL-XML  → eid:2-s2.0-85047402805
# 12:25:38 LEGACY        → doi:10.1016/j.envpol.2018.05.071
# 12:25:39   ✖ no full text
# 12:25:39 API-ENTITLED → doi:10.1016/j.ultsonch.2018.04.007
# 12:25:40 API-ENTITLED → doi:10.1093/chemse/bjy054
# 12:25:41 API-AMS       → doi:10.1093/chemse/bjy054
# 12:25:41 API-FULL-XML  → doi:10.1093/chemse/bjy054
# 12:25:42 API-ENTITLED → eid:2-s2.0-85061132217
# 12:25:42 API-AMS       → eid:2-s2.0-85061132217
# 12:25:43 API-FULL-XML  → eid:2-s2.0-85061132217
# 12:25:43 LEGACY        → doi:10.1093/chemse/bjy054
# 12:25:46   ✖ no full text
# 12:25:46 API-ENTITLED → doi:10.1002/smll.201802477
# 12:25:46 API-AMS       → doi:10.1002/smll.201802477
# 12:25:47 API-FULL-XML  → doi:10.1002/smll.201802477
# 12:25:48 API-ENTITLED → eid:2-s2.0-85052400089
# 12:25:49 API-AMS       → eid:2-s2.0-85052400089
# 12:25:50 API-FULL-XML  → eid:2-s2.0-85052400089
# 12:25:50 LEGACY        → doi:10.1002/smll.201802477
# 12:25:52   ✖ no full text
# 12:25:52 API-ENTITLED → doi:10.3390/molecules23092402
# 12:25:52 API-AMS       → doi:10.3390/molecules23092402
# 12:25:53 API-FULL-XML  → doi:10.3390/molecules23092402
# 12:25:53 API-ENTITLED → eid:2-s2.0-85053596955
# 12:25:54 API-AMS       → eid:2-s2.0-85053596955
# 12:25:54 API-FULL-XML  → eid:2-s2.0-85053596955
# 12:25:55 LEGACY        → doi:10.3390/molecules23092402
# 12:26:00 API-ENTITLED → doi:10.1186/s12870-018-1420-4
# 12:26:01 API-AMS       → doi:10.1186/s12870-018-1420-4
# 12:26:01 API-FULL-XML  → doi:10.1186/s12870-018-1420-4
# 12:26:02 API-ENTITLED → eid:2-s2.0-85053535867
# 12:26:02 API-AMS       → eid:2-s2.0-85053535867
# 12:26:03 API-FULL-XML  → eid:2-s2.0-85053535867
# 12:26:04 LEGACY        → doi:10.1186/s12870-018-1420-4
# 12:26:09 API-ENTITLED → doi:10.1016/j.scitotenv.2018.04.384
# 12:26:10 API-AMS       → doi:10.1016/j.scitotenv.2018.04.384
# 12:26:10 API-FULL-XML  → doi:10.1016/j.scitotenv.2018.04.384
# 12:26:11 API-ENTITLED → pii:S0048969718315699
# 12:26:12 API-AMS       → pii:S0048969718315699
# 12:26:13 API-FULL-XML  → pii:S0048969718315699
# 12:26:13 API-ENTITLED → eid:2-s2.0-85046786387
# 12:26:14 API-AMS       → eid:2-s2.0-85046786387
# 12:26:15 API-FULL-XML  → eid:2-s2.0-85046786387
# 12:26:15 LEGACY        → doi:10.1016/j.scitotenv.2018.04.384
# 12:26:17   ✖ no full text
# 12:26:17 API-ENTITLED → doi:10.1002/9781118801512.ch6
# 12:26:17 API-AMS       → doi:10.1002/9781118801512.ch6
# 12:26:18 API-FULL-XML  → doi:10.1002/9781118801512.ch6
# 12:26:18 API-ENTITLED → eid:2-s2.0-85050053742
# 12:26:19 API-AMS       → eid:2-s2.0-85050053742
# 12:26:19 API-FULL-XML  → eid:2-s2.0-85050053742
# 12:26:20 LEGACY        → doi:10.1002/9781118801512.ch6
# 12:26:21   ✖ no full text
# 12:26:21 API-ENTITLED → doi:10.3390/ijms19092702
# 12:26:22 API-AMS       → doi:10.3390/ijms19092702
# 12:26:22 API-FULL-XML  → doi:10.3390/ijms19092702
# 12:26:23 API-ENTITLED → eid:2-s2.0-85053320686
# 12:26:24 API-AMS       → eid:2-s2.0-85053320686
# 12:26:24 API-FULL-XML  → eid:2-s2.0-85053320686
# 12:26:25 LEGACY        → doi:10.3390/ijms19092702
#                                                 title  \
# 0   Application of superhydrophobic coatings as a ...
# 1   Epiisopilosine alkaloid has activity against s...
# 2   Surface properties and permeability to calcium...
# 3   Nano-selenium and its nanomedicine application...
# 4   Toxicological and bioactivity evaluation of bl...
# 5   Sporulation is dispensable for the vegetable-a...
# 6   Zoxamide accumulation and retention evaluation...
# 7   Quantitative trait locus mapping combined with...
# 8   Peptide-mediated targeting of nanoparticles wi...
# 9   Evaporating droplets on inclined plant leaves ...
# 10  Natural particles can armor emulsions against ...
# 11             Diversity and function of appressoria…
# 12  Evaluating the effects of pineapple fiber, pot...
# 13  A new cleaning method for solar panels inspire...
# 14  Elevating the photodecolorization efficiency f...
# 15  Transcriptome analysis of resistant and suscep...
# 16  Digital in-line holographic microscopy for lab...
# 17  Carbon investment into mobilization of mineral...
# 18  Synthesis and characterization of black curran...
# 19  Fire effects on C and H isotopic composition i...
# 20  Simulating stomatal response to cloud immersio...
# 21  Ultrasound assisted fabrication of a novel opt...
# 22  Characterization of ?-glucosidase inhibitors f...
# 23  Molecular genetic and biochemical evidence for...
# 24  Characterization and functional analysis of Fa...
#
#                                               journal  \
# 0                     Surface and Coatings Technology
# 1                                            PLoS ONE
# 2                          Frontiers in Plant Science
# 3               International Journal of Nanomedicine
# 4                        Food and Chemical Toxicology
# 5                             Microbial Biotechnology
# 6                             Pest Management Science
# 7                    Theoretical and Applied Genetics
# 8                                        Bio-protocol
# 9            Journal of Colloid and Interface Science
# 10                                     Food Chemistry
# 11                                          Pathogens
# 12                             Results in Engineering
# 13                                 Scientific Reports
# 14  Case Studies in Chemical and Environmental Eng...
# 15                                  BMC Plant Biology
# 16                          Military Medical Research
# 17                     Biology and Fertility of Soils
# 18               Iraqi Journal of Veterinary Medicine
# 19                   Science of the Total Environment
# 20                Agricultural and Forest Meteorology
# 21                          Ultrasonics Sonochemistry
# 22                                          Molecules
# 23                                  BMC Plant Biology
# 24        International Journal of Molecular Sciences
#
#                            authors  year                              doi  \
# 0                   Vazirinasab E.  2018   10.1016/j.surfcoat.2017.11.053
# 1                   Guimarães M.A.  2018     10.1371/journal.pone.0196667
# 2                   Bahamonde H.A.  2018          10.3389/fpls.2018.00494
# 3                    Hosnedlova B.  2018              10.2147/IJN.S157541
# 4                           Pap N.  2021        10.1016/j.fct.2021.112284
# 7                            Qi P.
# 8                       Santana I.
# 9                   Tredenick E.C.
# 10                     Schröder A.
# 11           Thilini Chethana K.W.
# 12  Keerthiveettil Ramakrishnan S.
# 13                 Abd-Elhady M.S.
# 14                      Subagyo R.
# 15                     Botkin J.R.
# 16                          Kim J.
# 17                      Andrino A.
# 18                   Al-Kurdy M.J.
# 19            Jiménez-Morillo N.T.
# 20                   Lowman L.E.L.
# 21                      Parsaee Z.
# 22                     Murugesu S.
# 23                       Yang C.K.
# 24                       Zhuang L.
#
#                                               journal  year  \
# 0                     Surface and Coatings Technology  2018
# 1                                            PLoS ONE  2018
# 2                          Frontiers in Plant Science  2018
# 3               International Journal of Nanomedicine  2018
# 4                        Food and Chemical Toxicology  2021
# 5                             Microbial Biotechnology  2021
# 6                             Pest Management Science  2021
# 7                    Theoretical and Applied Genetics  2021
# 8                                        Bio-protocol  2021
# 9            Journal of Colloid and Interface Science  2021
# 10                                     Food Chemistry  2021
# 11                                          Pathogens  2021
# 12                             Results in Engineering  2024
# 13                                 Scientific Reports  2024
# 14  Case Studies in Chemical and Environmental Eng...  2024
# 15                                  BMC Plant Biology  2024
# 16                          Military Medical Research  2024
# 17                     Biology and Fertility of Soils  2021
# 18               Iraqi Journal of Veterinary Medicine  2020
# 19                   Science of the Total Environment  2020
# 20                Agricultural and Forest Meteorology  2020
# 21                          Ultrasonics Sonochemistry  2018
# 22                                          Molecules  2018
# 23                                  BMC Plant Biology  2018
# 24        International Journal of Molecular Sciences  2018
#
#                                             full_text
# 0   ../data/downloads/10.1016_j.surfcoat.2017.11.0...
# 1   ../data/downloads/10.1371_journal.pone.0196667...
# 2    ../data/downloads/10.3389_fpls.2018.00494_OA.pdf
# 3        ../data/downloads/10.2147_IJN.S157541_OA.pdf
# 4     ../data/downloads/10.1016_j.fct.2021.112284.pdf
# 5    ../data/downloads/10.1111_1751-7915.13816_OA.pdf
# 6            ../data/downloads/10.1002_ps.6404_OA.pdf
# 7   ../data/downloads/10.1007_s00122-021-03798-y_O...
# 8    ../data/downloads/10.21769_BioProtoc.4060_OA.pdf
# 9   ../data/downloads/10.1016_j.jcis.2021.01.070_O...
# 10  ../data/downloads/10.1016_j.foodchem.2021.1290...
# 11  ../data/downloads/10.3390_pathogens10060746_OA...
# 12  ../data/downloads/10.1016_j.rineng.2024.102974...
# 13  ../data/downloads/10.1038_s41598-024-68215-y_O...
# 14  ../data/downloads/10.1016_j.cscee.2024.100875.pdf
# 15  ../data/downloads/10.1186_s12870-024-05444-3_O...
# 16  ../data/downloads/10.1186_s40779-024-00541-8_O...
# 17  ../data/downloads/10.1007_s00374-020-01505-5_O...
# 18   ../data/downloads/10.30539_IJVM.V44I2.974_OA.pdf
# 19  ../data/downloads/10.1016_j.scitotenv.2020.141...
# 20  ../data/downloads/10.1016_j.agrformet.2020.108...
# 21  ../data/downloads/10.1016_j.ultsonch.2018.04.0...
# 22  ../data/downloads/10.3390_molecules23092402_OA...
# 23  ../data/downloads/10.1186_s12870-018-1420-4_OA...
# 24      ../data/downloads/10.3390_ijms19092702_OA.pdf
