# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ## Question 1: How much data
#
# Search 1: A simple, broad search of literature regarding hydrophobicity in plant leaves.
#
# `Hydrophobicity AND plant leaves`

# %%
import os
import requests
import pandas as pd
import random
import pathlib
import re
import time
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")


query_string = 'Hydrophobi*+"plant+leaves"'
encoded_query = query_string  # → Hydrophobicity+AND+%22plant+leaves%22

RESOURCE_URL = "https://api.elsevier.com/"
SEARCH_URL = f"{RESOURCE_URL}/content/search/scopus"
ARTICLE_URL = f"{RESOURCE_URL}/content/article"

headers = {
    "X-ELS-APIKey": api_key,
    "Accept": "application/json",
}
params_counting_only = {
    "query": encoded_query,
    "count": 0,
}

# Hit count
r_count = requests.get(SEARCH_URL, headers=headers, params=params_counting_only)
r_count.raise_for_status()

total_hits = int(r_count.json()["search-results"]["opensearch:totalResults"])

print(f"Total hits for {encoded_query}: {total_hits}")

LIMIT = 25

params = {
    "query": encoded_query,
    "count": LIMIT,
}

resp = requests.get(SEARCH_URL, headers=headers, params=params)

if resp.status_code != 200:
    raise RuntimeError(f"Scopus API error {resp.status_code}: {resp.text}")

entries = resp.json().get("search-results", {}).get("entry", [])
records = [
    {
        "Title": e.get("dc:title"),
        "Authors": e.get("dc:creator"),
        "Year": e.get("prism:coverDate", "").split("-")[0],
        "URL": e.get("prism:url"),
    }
    for e in entries
]
df = pd.DataFrame(records)
print(f"Returned {len(df)} documents")
display(df)  # in a notebook this renders a nice HTML table
# df.to_csv("scopus_results.csv", index=False)   # optional persist
# Out:
# Total hits for Hydrophobi*+"plant+leaves": 6218
# Returned 25 documents
#                                                 Title              Authors  \
# 0   The suberin transporter StABCG1 is required fo...  Benatto Perino E.H.
# 1   Combining plant extracts and hot water treatme...             Worku S.
# 2   Sustainable pest management using plant second...             Zhang X.
# 3   Plant Cell Wall-Like Soft Materials: Micro- an...           Koshani R.
# 4   Anti-proliferative and photodynamic activities...       Olofinsan K.A.
# 5   Optimization of betulinic and ursolic acids an...           Demiray H.
# 6   De novo assembly of the mitochondrial genome o...              Zhou G.
# 7   Discovery of potent anti-toxoplasmosis drugs f...      Mohammed M.M.D.
# 8   The nano-paradox: addressing nanotoxicity for ...          Rajpal V.R.
# 9   Understanding ultrafast free-rising bubble cap...                Hu Y.
# 10  Chemical profile, virtual screening, and virul...        Hassan W.H.B.
# 11  In vitro and in silico pharmacological effects...        Alaboudi K.A.
# 12  Review on the need for inventories and managem...             Weber R.
# 13  A supramolecular bactericidal material for pre...              Yang J.
# 14  Innovative applications of SERS in precision m...              Chen B.
# 15  Research on underwater air layer retention and...               Sun H.
# 16  Insights into structure-antioxidant activity r...             Xiang Y.
# 17  High-Performance green fluorescent carbon Dots...              Wang Y.
# 18  A general strategy to enhance surface hydropho...              Chen X.
# 19  Enhancing fog harvesting efficiency with a mul...               Luo J.
# 20  Polylactic acid microplastics and earthworms d...              Chen C.
# 21  Unveiling the impact of soil depth on degradat...               Xie Y.
# 22  Understanding the response mechanisms of C4 an...                Xu X.
# 23  Low-dose natural clay Kaolin promotes the grow...               Sun S.
# 24  Understanding the adsorption of imidazo-pyrimi...          Ansari K.R.
#
#     Year                                                URL
# 0   2025  https://api.elsevier.com/content/abstract/scop...
# 1   2025  https://api.elsevier.com/content/abstract/scop...
# 2   2025  https://api.elsevier.com/content/abstract/scop...
# 3   2025  https://api.elsevier.com/content/abstract/scop...
# 4   2025  https://api.elsevier.com/content/abstract/scop...
# 5   2025  https://api.elsevier.com/content/abstract/scop...
# 6   2025  https://api.elsevier.com/content/abstract/scop...
# 7   2025  https://api.elsevier.com/content/abstract/scop...
# 8   2025  https://api.elsevier.com/content/abstract/scop...
# 9   2025  https://api.elsevier.com/content/abstract/scop...
# 10  2025  https://api.elsevier.com/content/abstract/scop...
# 11  2025  https://api.elsevier.com/content/abstract/scop...
# 12  2025  https://api.elsevier.com/content/abstract/scop...
# 13  2025  https://api.elsevier.com/content/abstract/scop...
# 14  2025  https://api.elsevier.com/content/abstract/scop...
# 15  2025  https://api.elsevier.com/content/abstract/scop...
# 16  2025  https://api.elsevier.com/content/abstract/scop...
# 17  2025  https://api.elsevier.com/content/abstract/scop...
# 18  2025  https://api.elsevier.com/content/abstract/scop...
# 19  2025  https://api.elsevier.com/content/abstract/scop...
# 20  2025  https://api.elsevier.com/content/abstract/scop...
# 21  2025  https://api.elsevier.com/content/abstract/scop...
# 22  2025  https://api.elsevier.com/content/abstract/scop...
# 23  2025  https://api.elsevier.com/content/abstract/scop...
# 24  2025  https://api.elsevier.com/content/abstract/scop...

# %% [markdown]
# Here we have a good first look at some very coarse-grained results. Let's go in and use random offsets to retrieve 25 random documents.

# %%
from requests.adapters import HTTPAdapter, Retry


# ------------------------------------------------------------------
# Configuration
# ------------------------------------------------------------------
load_dotenv()
API_KEY = os.getenv("API_KEY")  # ← your Elsevier key
EMAIL = os.getenv("EMAIL")  # ← required by Unpaywall
DL_DIR = pathlib.Path("downloads")
DL_DIR.mkdir(exist_ok=True)

TARGET = 25  # how many full-text docs we want
SEARCH_PAGE_SZ = 25  # pull 25 hits per random page
MAX_OFFSET = 5000 - SEARCH_PAGE_SZ  # Scopus hard cap with start=

hdrs_core = {"X-ELS-APIKey": API_KEY}
hdrs_xml = {**hdrs_core, "Accept": "text/xml"}
hdrs_pdf = {**hdrs_core, "Accept": "application/pdf"}


def log(msg):
    print(time.strftime("%H:%M:%S"), msg)


# ------------------------------------------------------------------
# Helper functions
# ------------------------------------------------------------------
def extract_data(entry: dict) -> dict:
    """Return data (if present) from a search entry."""
    eid = entry.get("eid") or entry.get("dc:identifier", "").split(":")[-1]
    return {
        "eid": eid,
        "doi": entry.get("prism:doi"),
        "pii": entry.get("pii"),
        "title": entry.get("dc:title", "")[:80] + "…",
        "authors": entry.get("dc:creator"),
        "journal": entry.get("prism:publicationName"),
        "year": entry.get("prism:coverDate", "").split("-")[0],
    }


# ... keep existing imports

# ------------------------------------------------------------------
#  robust Session  (re-use everywhere)
# ------------------------------------------------------------------
S = requests.Session()
retries = Retry(
    total=4,  # max 4 attempts
    backoff_factor=0.4,  # 0.4, 0.8, 1.6, 3.2 s
    status_forcelist=[502, 503, 504, 429],
    allowed_methods=["GET"],
)
S.mount("https://", HTTPAdapter(max_retries=retries))
S.headers.update({"X-ELS-APIKey": API_KEY})  # applied to every request

# dedicated headers for full-text
HDR_XML = {"Accept": "text/xml"}
HDR_PDF = {"Accept": "application/pdf"}

DELAY = 0.3  # polite pause after every outgoing request


# ------------------------------------------------------------------
def save(url: str, path: pathlib.Path, hdr: dict) -> bool:
    """Try to download url → path (with retries); return True if saved."""
    try:
        r = S.get(url, headers=hdr, stream=True, timeout=30, allow_redirects=True)
        time.sleep(DELAY)
        if r.status_code == 200:
            with path.open("wb") as fh:
                for chunk in r.iter_content(8192):
                    fh.write(chunk)
            return True
    except requests.RequestException as exc:
        log(f"      …download error ({exc.__class__.__name__}) – skipped")
    return False


# ------------------------------------------------------------------
FULL_TEXT_MARKER = re.compile(rb"<ce:section\b", re.I)

def try_sciencedirect(ids):
    """Return path of saved PDF or *real* full-text XML, else None."""
    for key in ("doi", "pii", "eid"):
        val = ids.get(key)
        if not val:
            continue

        # ---------- 1) PDF first ----------
        pdf_name = DL_DIR / f"{val.replace('/', '_')}.pdf"
        if pdf_name.exists() or save(f"{ARTICLE_URL}/{key}/{val}", pdf_name, HDR_PDF):
            return pdf_name

        # ---------- 2) XML – but keep only if it looks like FULL view ----------
        xml_name = DL_DIR / f"{val.replace('/', '_')}.xml"
        if xml_name.exists() or save(f"{ARTICLE_URL}/{key}/{val}", xml_name, HDR_XML):
            # peek at first 8 kB to decide
            with xml_name.open("rb") as fh:
                head = fh.read(8192)
            if FULL_TEXT_MARKER.search(head):
                return xml_name
            else:
                xml_name.unlink(missing_ok=True)   # drop stub
    return None


# ------------------------------------------------------------------
def try_unpaywall(doi):
    if not doi:
        return None
    meta = S.get(
        f"https://api.unpaywall.org/v2/{doi}", params={"email": EMAIL}, timeout=15
    )
    time.sleep(DELAY)
    pdf = (meta.json().get("best_oa_location") or {}).get("url_for_pdf")
    if pdf:
        fname = DL_DIR / f"{doi.replace('/', '_')}_OA.pdf"
        if fname.exists() or save(pdf, fname, hdr={}):
            return fname
    return None


# ------------------------------------------------------------------

# ------------------------------------------------------------------
# Main sampling loop
# ------------------------------------------------------------------
fulltext_records, seen_eids = [], set()
upper_bound = min(
    MAX_OFFSET,
    int(r_count.json()["search-results"]["opensearch:totalResults"]) - SEARCH_PAGE_SZ,
)

while len(fulltext_records) < TARGET:
    start = random.randint(0, upper_bound)
    params = {"query": encoded_query, "count": SEARCH_PAGE_SZ, "start": start}
    page = requests.get(SEARCH_URL, headers=hdrs_core, params=params)
    page.raise_for_status()
    entries = page.json()["search-results"].get("entry", [])
    log(f"Scanned page @offset {start:,}")

    for e in entries:
        ids = extract_data(e)
        if ids["eid"] in seen_eids:  # avoid duplicates
            continue
        seen_eids.add(ids["eid"])

        # ---------- attempt full-text ----------
        path = try_sciencedirect(ids)
        if not path:
            path = try_unpaywall(ids["doi"])
        if path:
            ids["full_text"] = str(path)
            fulltext_records.append(ids)
            log(f"  ✔ saved {path.name}   ({len(fulltext_records)}/{TARGET})")
            break  # loop will pick a new offset
        else:
            log("  ✖ no full text")

        if len(fulltext_records) == TARGET:
            break

df_full = pd.DataFrame(fulltext_records)
cols = ["title", "journal", "authors", "year", "doi", "full_text"]
display(df_full[cols])
df_full.to_csv("random25_fulltext.csv", index=False)
log("Completed – 25 full-text documents obtained.")
# Out:
# 15:28:03 Scanned page @offset 533
# 15:28:04   ✔ saved 10.1016_j.jobe.2024.110635.pdf   (1/25)
# 15:28:05 Scanned page @offset 1,255
# 15:28:07   ✔ saved 10.1016_j.jsps.2023.101762.pdf   (2/25)
# 15:28:08 Scanned page @offset 4,219
# 15:28:11   ✖ no full text
# 15:28:12   ✔ saved 10.1016_j.plaphy.2015.09.007.pdf   (3/25)
# 15:28:13 Scanned page @offset 4,274
# 15:28:14   ✔ saved 10.4315_0362-028X.JFP-15-056.pdf   (4/25)
# 15:28:15 Scanned page @offset 625
# 15:28:16   ✔ saved 10.1016_j.sajb.2024.07.048.pdf   (5/25)
# 15:28:17 Scanned page @offset 2,374
# 15:28:24   ✔ saved 10.3389_fmicb.2021.738058_OA.pdf   (6/25)
# 15:28:25 Scanned page @offset 4,459
# 15:28:26   ✔ saved 10.1016_j.msec.2014.07.022.pdf   (7/25)
# 15:28:26 Scanned page @offset 3,639
# 15:28:29   ✖ no full text
# 15:28:30   ✔ saved 10.1016_j.phymed.2018.03.051.pdf   (8/25)
# 15:28:31 Scanned page @offset 1,075
# 15:28:34   ✖ no full text
# 15:28:37   ✖ no full text
# 15:28:44   ✔ saved 10.3389_fsufs.2024.1343615_OA.pdf   (9/25)
# 15:28:45 Scanned page @offset 4,052
# 15:28:46   ✔ saved 10.1016_j.apsusc.2016.02.090.pdf   (10/25)
# 15:28:47 Scanned page @offset 3,256
# 15:28:48   ✔ saved 10.1016_j.jallcom.2019.04.169.pdf   (11/25)
# 15:28:49 Scanned page @offset 1,910
# 15:28:50   ✔ saved 10.1016_j.orggeochem.2022.104463.pdf   (12/25)
# 15:28:51 Scanned page @offset 673
# 15:28:56   ✔ saved 10.3390_app14166993_OA.pdf   (13/25)
# 15:28:57 Scanned page @offset 1,119
# 15:29:01   ✖ no full text
# 15:29:04   ✖ no full text
# 15:29:07   ✖ no full text
# 15:29:10   ✖ no full text
# 15:29:13   ✖ no full text
# 15:29:16   ✖ no full text
# 15:29:22   ✔ saved 10.1080_03067319.2022.2060088_OA.pdf   (14/25)
# 15:29:23 Scanned page @offset 3,984
# 15:29:24   ✔ saved 10.1016_j.orggeochem.2016.10.016.pdf   (15/25)
# 15:29:25 Scanned page @offset 2,265
# 15:29:26   ✔ saved 10.1016_j.jchromb.2021.123006.pdf   (16/25)
# 15:29:27 Scanned page @offset 4,046
# 15:29:30   ✖ no full text
# 15:29:31   ✖ no full text
# 15:29:32   ✖ no full text
# 15:29:33   ✔ saved 10.1016_j.pep.2015.09.009.pdf   (17/25)
# 15:29:34 Scanned page @offset 3,194
# 15:29:37   ✖ no full text
# 15:29:38   ✔ saved 10.1016_j.toxicon.2019.10.244.pdf   (18/25)
# 15:29:51 Scanned page @offset 878
# 15:29:52   ✔ saved 10.1016_j.cej.2024.150061.pdf   (19/25)
# 15:29:53 Scanned page @offset 4,294
# 15:29:56   ✖ no full text
# 15:29:57   ✔ saved 10.1016_S2222-1808(15)60826-X.pdf   (20/25)
# 15:29:58 Scanned page @offset 1,176
# 15:29:59   ✔ saved 10.1016_j.pbi.2023.102441.pdf   (21/25)
# 15:30:00 Scanned page @offset 1,395
# 15:30:04   ✔ saved 10.1016_j.jes.2022.09.013.pdf   (22/25)
# 15:30:08 Scanned page @offset 4,865
# 15:30:10   ✖ no full text
# 15:30:14   ✖ no full text
# 15:30:17   ✖ no full text
# 15:30:22   ✔ saved 10.3390_molecules171214323_OA.pdf   (23/25)
# 15:30:22 Scanned page @offset 1,781
# 15:30:24   ✔ saved 10.1016_j.tibtech.2022.09.013.pdf   (24/25)
# 15:30:25 Scanned page @offset 2,386
# 15:30:26   ✔ saved 10.1016_j.colsurfa.2021.126794.pdf   (25/25)
#                                                 title  \
# 0   Preparation of composite superhydrophobic coat...
# 1   Multi-target action of Garcinia livingstonei e...
# 2   Identification and functional analysis of the ...
# 3   Role of cellulose and colanic acid in attachme...
# 4   Exploring the cytoprotective potential of flav...
# 5   Prospecting Endophytic Bacteria Endowed With P...
# 6   Preparation and hydrophobicity of biomorphic Z...
# 7   Anti-inflammatory and antioxidant activities o...
# 8   Effects of alkaline and ultrasonication on duc...
# 9   Fabrication of biomimetic superhydrophobic ste...
# 10  A simple two-step approach for the fabrication...
# 11  Understanding the disparity in n-alkane produc...
# 12  Combined Process for Caffeine Treatment in Aqu...
# 13  A comparative study of CuO nanoparticle and Cu...
# 14  Extracting the most from terrestrial plant-der...
# 15  Development, validation, and application of an...
# 16  Production of bioactive wheat puroindoline pro...
# 17  Cyclotides: Disulfide-rich peptide toxins in p...
# 18  Facilely construct of GSH-responsive nanogel b...
# 19  An insight into medicinal and ethnopharmacolog...
# 20  Improving RNA-based crop protection through na...
# 21  Polycyclic aromatic hydrocarbons (PAHs) in a s...
# 22  Ionic liquid-based microwave-Assisted extracti...
# 23  Biorefining waste into nanobiotechnologies can...
# 24  Magnetic superhydrophobic polyurethane sponge ...
#
#                                               journal            authors  \
# 0                     Journal of Building Engineering              Lu L.
# 1                        Saudi Pharmaceutical Journal  Abdul-Rahman A.M.
# 2                   Plant Physiology and Biochemistry            Deng Y.
# 3                          Journal of Food Protection           Lee C.C.
# 4                     South African Journal of Botany         Kumar S.S.
# 5                           Frontiers in Microbiology      Hazarika S.N.
# 6                 Materials Science and Engineering C            Wang T.
# 7                                       Phytomedicine     El-desoky A.H.
# 8               Frontiers in Sustainable Food Systems  Nitiwuttithorn C.
# 9                             Applied Surface Science             Yin L.
# 10                    Journal of Alloys and Compounds            Lian Z.
# 11                               Organic Geochemistry        Dasgupta B.
# 12                     Applied Sciences (Switzerland)       Zanatta N.P.
# 13  International Journal of Environmental Analyti...           Ghosh N.
# 14                               Organic Geochemistry    Diefendorf A.F.
# 15  Journal of Chromatography B: Analytical Techno...   Almeida-Trapp M.
# 16                Protein Expression and Purification        Niknejad A.
# 17                                            Toxicon         Huang Y.H.
# 18                       Chemical Engineering Journal              Xu X.
