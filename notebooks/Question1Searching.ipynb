# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ## Question 1: How much data
#
# Search 1: A simple, broad search of literature regarding hydrophobicity in plant leaves.
#
# `Hydrophobicity AND plant leaves`

# %%
import os
import requests
import pandas as pd
from urllib.parse import quote_plus      # quote_plus turns blanks → “+” and quotes → “%22”
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")


query = 'Hydrophobi*%20AND%20"plant+leaves"'    
encoded_query = query               # → Hydrophobicity+AND+%22plant+leaves%22

print(encoded_query)

url = "https://api.elsevier.com/content/search/scopus"
headers = {
    "X-ELS-APIKey": api_key,
    "Accept": "application/json",
}
params = {
    "query": encoded_query,
    "count": 25,
}

resp = requests.get(url, headers=headers, params=params)

if resp.status_code != 200:
    raise RuntimeError(f"Scopus API error {resp.status_code}: {resp.text}")

entries = resp.json().get("search-results", {}).get("entry", [])
records = [
    {
        "Title":   e.get("dc:title"),
        "Authors": e.get("dc:creator"),
        "Year":    e.get("prism:coverDate", "").split("-")[0],
        "URL":     e.get("prism:url"),
    }
    for e in entries
]
df = pd.DataFrame(records)
print(f"Returned {len(df)} documents")
display(df)          # in a notebook this renders a nice HTML table
# df.to_csv("scopus_results.csv", index=False)   # optional persist
# Out:
# Hydrophobi*%20AND%20"plant+leaves"
# Returned 25 documents
#                                                 Title             Authors  \
# 0   Mycological inventions for sustainable agricul...        Kashyap A.K.
# 1   Formulation and optimization study of nanodeli...         Nguyen P.V.
# 2   Radiochemical Analysis of Agrochemicals: Envir...        Jalal M.A.F.
# 3   Molecular mechanisms of plant productivity enh...              Dey A.
# 4        Aquatic animal nutrition: Plant preparations    Steinberg C.E.W.
# 5   Phyllosphere microbial plant pathogens: Detect...     Narayanasamy P.
# 6          What are the 100 most cited fungal genera?        Bhunjun C.S.
# 7   Plant adaptation to abiotic stress: From signa...          Chaffai R.
# 8   Harnessing NanoOmics and nanozymes for sustain...         Rajput V.D.
# 9   Violaceae: chemical constituents, traditional ...  Fernández-Bobey A.
# 10  Plant leaf proanthocyanidins: from agricultura...             Zhou W.
# 11  Green leaf proteins: a sustainable source of e...           Hadidi M.
# 12  Ethnomedical Use, Phytochemistry, Nutritional ...          Worku L.A.
# 13  Research Progress of Nucleic Acid Detection Te...              Luo T.
# 14  Recent Advancements in Plant- and Microbe-Medi...             Rana A.
# 15  Valorization of Campomanesia xanthocarpa leave...       Sugauara R.R.
# 16  Purification and thermodynamic characterizatio...            Zaman U.
# 17  Leaf Wettability Difference Among Tea Leaf Age...              Pan Q.
# 18  Rationale utilization of phospholipid excipien...         Jebastin K.
# 19  Mobilization of Per- and Polyfluoroalkyl Subst...      Abou-Khalil C.
# 20  Adsorption of crude oil from aqueous solution:...        Emenike E.C.
# 21  Sustainable re-utilization of waste materials ...          Ngeno E.C.
# 22  New approaches with ATR-FTIR, SEM, and contact...          Kayabaş A.
# 23  Overview of the development of slippery surfac...             Wang X.
# 24  Phytoremediation: An eco-friendly, sustainable...           Sarkar M.
#
#     Year                                                URL
# 0   2025  https://api.elsevier.com/content/abstract/scop...
# 1   2025  https://api.elsevier.com/content/abstract/scop...
# 2   2025  https://api.elsevier.com/content/abstract/scop...
# 3   2024  https://api.elsevier.com/content/abstract/scop...
# 4   2024  https://api.elsevier.com/content/abstract/scop...
# 5   2024  https://api.elsevier.com/content/abstract/scop...
# 6   2024  https://api.elsevier.com/content/abstract/scop...
# 7   2024  https://api.elsevier.com/content/abstract/scop...
# 8   2024  https://api.elsevier.com/content/abstract/scop...
# 9   2024  https://api.elsevier.com/content/abstract/scop...
# 10  2024  https://api.elsevier.com/content/abstract/scop...
# 11  2024  https://api.elsevier.com/content/abstract/scop...
# 12  2024  https://api.elsevier.com/content/abstract/scop...
# 13  2023  https://api.elsevier.com/content/abstract/scop...
# 14  2023  https://api.elsevier.com/content/abstract/scop...
# 15  2023  https://api.elsevier.com/content/abstract/scop...
# 16  2023  https://api.elsevier.com/content/abstract/scop...
# 17  2023  https://api.elsevier.com/content/abstract/scop...
# 18  2023  https://api.elsevier.com/content/abstract/scop...
# 19  2022  https://api.elsevier.com/content/abstract/scop...
# 20  2022  https://api.elsevier.com/content/abstract/scop...
# 21  2022  https://api.elsevier.com/content/abstract/scop...
# 22  2022  https://api.elsevier.com/content/abstract/scop...
# 23  2022  https://api.elsevier.com/content/abstract/scop...
# 24  2022  https://api.elsevier.com/content/abstract/scop...
