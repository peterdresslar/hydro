# %%
# %load_ext dotenv
# %dotenv ../.env
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# ## Question 1: How much data
#
# Search 1: A simple, broad search of literature regarding hydrophobicity in plant leaves.
#
# `Hydrophobicity AND plant leaves`

# %%
import os
import requests
import pandas as pd
from urllib.parse import quote_plus      # quote_plus turns blanks → “+” and quotes → “%22”
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("API_KEY")


query_string = 'Hydrophobi*+"plant+leaves"'    
encoded_query = query_string               # → Hydrophobicity+AND+%22plant+leaves%22

RESOURCE_URL = "https://api.elsevier.com/content/search/scopus"
headers = {
    "X-ELS-APIKey": api_key,
    "Accept": "application/json",
}
params_counting_only = {
    "query": encoded_query,
    "count": 0,
}

# Hit count
r_count = requests.get(RESOURCE_URL, headers=headers, params=params_counting_only)
r_count.raise_for_status()

total_hits = int(r_count.json()["search-results"]["opensearch:totalResults"])

print(f"Total hits for {encoded_query}: {total_hits}")

LIMIT = 25

params = {
    "query": encoded_query,
    "count": LIMIT,
}

resp = requests.get(RESOURCE_URL, headers=headers, params=params)

if resp.status_code != 200:
    raise RuntimeError(f"Scopus API error {resp.status_code}: {resp.text}")

entries = resp.json().get("search-results", {}).get("entry", [])
records = [
    {
        "Title":   e.get("dc:title"),
        "Authors": e.get("dc:creator"),
        "Year":    e.get("prism:coverDate", "").split("-")[0],
        "URL":     e.get("prism:url"),
    }
    for e in entries
]
df = pd.DataFrame(records)
print(f"Returned {len(df)} documents")
display(df)          # in a notebook this renders a nice HTML table
# df.to_csv("scopus_results.csv", index=False)   # optional persist
# Out:
# Total hits for Hydrophobi*+"plant+leaves": 6215
# Returned 25 documents
#                                                 Title              Authors  \
# 0   The suberin transporter StABCG1 is required fo...  Benatto Perino E.H.
# 1   Combining plant extracts and hot water treatme...             Worku S.
# 2   Sustainable pest management using plant second...             Zhang X.
# 3   Plant Cell Wall-Like Soft Materials: Micro- an...           Koshani R.
# 4   Anti-proliferative and photodynamic activities...       Olofinsan K.A.
# 5   Optimization of betulinic and ursolic acids an...           Demiray H.
# 6   De novo assembly of the mitochondrial genome o...              Zhou G.
# 7   Discovery of potent anti-toxoplasmosis drugs f...      Mohammed M.M.D.
# 8   The nano-paradox: addressing nanotoxicity for ...          Rajpal V.R.
# 9   Understanding ultrafast free-rising bubble cap...                Hu Y.
# 10  Chemical profile, virtual screening, and virul...        Hassan W.H.B.
# 11  In vitro and in silico pharmacological effects...        Alaboudi K.A.
# 12  Review on the need for inventories and managem...             Weber R.
# 13  A supramolecular bactericidal material for pre...              Yang J.
# 14  Innovative applications of SERS in precision m...              Chen B.
# 15  Research on underwater air layer retention and...               Sun H.
# 16  Insights into structure-antioxidant activity r...             Xiang Y.
# 17  High-Performance green fluorescent carbon Dots...              Wang Y.
# 18  A general strategy to enhance surface hydropho...              Chen X.
# 19  Enhancing fog harvesting efficiency with a mul...               Luo J.
# 20  Polylactic acid microplastics and earthworms d...              Chen C.
# 21  Unveiling the impact of soil depth on degradat...               Xie Y.
# 22  Understanding the response mechanisms of C4 an...                Xu X.
# 23  Low-dose natural clay Kaolin promotes the grow...               Sun S.
# 24  Understanding the adsorption of imidazo-pyrimi...          Ansari K.R.
#
#     Year                                                URL
# 0   2025  https://api.elsevier.com/content/abstract/scop...
# 1   2025  https://api.elsevier.com/content/abstract/scop...
# 2   2025  https://api.elsevier.com/content/abstract/scop...
# 3   2025  https://api.elsevier.com/content/abstract/scop...
# 4   2025  https://api.elsevier.com/content/abstract/scop...
# 5   2025  https://api.elsevier.com/content/abstract/scop...
# 6   2025  https://api.elsevier.com/content/abstract/scop...
# 7   2025  https://api.elsevier.com/content/abstract/scop...
# 8   2025  https://api.elsevier.com/content/abstract/scop...
# 9   2025  https://api.elsevier.com/content/abstract/scop...
# 10  2025  https://api.elsevier.com/content/abstract/scop...
# 11  2025  https://api.elsevier.com/content/abstract/scop...
# 12  2025  https://api.elsevier.com/content/abstract/scop...
# 13  2025  https://api.elsevier.com/content/abstract/scop...
# 14  2025  https://api.elsevier.com/content/abstract/scop...
# 15  2025  https://api.elsevier.com/content/abstract/scop...
# 16  2025  https://api.elsevier.com/content/abstract/scop...
# 17  2025  https://api.elsevier.com/content/abstract/scop...
# 18  2025  https://api.elsevier.com/content/abstract/scop...
# 19  2025  https://api.elsevier.com/content/abstract/scop...
# 20  2025  https://api.elsevier.com/content/abstract/scop...
# 21  2025  https://api.elsevier.com/content/abstract/scop...
# 22  2025  https://api.elsevier.com/content/abstract/scop...
# 23  2025  https://api.elsevier.com/content/abstract/scop...
# 24  2025  https://api.elsevier.com/content/abstract/scop...

# %% [markdown]
# Here we have a good first look at some very coarse-grained results. Let's go in and use random offsets to retrieve 25 random documents.

# %%
import random

# ------------------------------------------------------------
# 4. grab 25 random records in 5 small pages (5 records each)
# ------------------------------------------------------------
SAMPLE_PAGES = 5
PAGE_SIZE    = 5
MAX_OFFSET   = 5000 - PAGE_SIZE          # Scopus hard limit with `start=` paging

if total_hits <= SAMPLE_PAGES * PAGE_SIZE:
    print("\nNo random sampling necessary – the result-set is small.")
else:
    upper_bound = min(total_hits - PAGE_SIZE, MAX_OFFSET)
    random_starts = random.sample(range(0, upper_bound + 1), SAMPLE_PAGES)

    print("Sampling from the following offsets:")
    print(random_starts)

    sample_records = []
    for s in sorted(random_starts):
        params_rand = {
            "query": encoded_query,
            "count": PAGE_SIZE,
            "start": s                 # 0-based offset into the results
        }
        r_rand = requests.get(RESOURCE_URL, headers=headers, params=params_rand)
        r_rand.raise_for_status()

        for e in r_rand.json()["search-results"].get("entry", []):
            sample_records.append({
                "Title":   e.get("dc:title"),
                "Authors": e.get("dc:creator"),
                "Year":    e.get("prism:coverDate", "").split("-")[0],
                "URL":     e.get("prism:url"),
            })

    df_rand = pd.DataFrame(sample_records)
    print(f"\nRandom sample of {len(df_rand)} documents "
          f"pulled in {SAMPLE_PAGES} queries "
          f"(offsets ≤ {MAX_OFFSET}).")
    display(df_rand)
# Out:
# Sampling from the following offsets:
# [3265, 4235, 4803, 1212, 3604]
#
# Random sample of 25 documents pulled in 5 queries (offsets ≤ 4995).
#                                                 Title            Authors  \
# 0   Unraveling the interplay of leaf structure and...         Ganar S.S.
# 1   Dehydrin CaDHN2 Enhances Drought Tolerance by ...              Li X.
# 2   Foliar Application of Sulfur-Containing Compou...      Bouranis D.L.
# 3   Neither lysigenous nor just oil: Demystifying ...        Richit J.F.
# 4   Particle Size Effect of Cyetpyrafen Formulatio...              Yu L.
# 5   Surface topographies of biomimetic superamphip...             Gou X.
# 6   Rotator phases in alkane systems: In bulk, sur...       Cholakova D.
# 7   Hydrophobin HFBII-4 from Trichoderma asperellu...           Zhang H.
# 8   Metabolic markers for the yield of lipophilic ...      Nguyen T.K.O.
# 9   An investigation on the leaf accumulation-remo...           Zhang L.
# 10  An Atypical Late Embryogenesis Abundant Protei...           Huang L.
# 11  DEWAX2 Transcription Factor Negatively Regulat...             Kim H.
# 12  Epiisopilosine alkaloid has activity against s...     Guimarães M.A.
# 13  The key gluconeogenic gene PCK1 is crucial for...           Liu J.K.
# 14  Insulin releasing effect of some pure compound...       Hafizur R.M.
# 15  Effects of Rhodomyrtus tomentosa leaf extract ...       Mordmuang A.
# 16  FAS Grafted Electrospun Poly(vinyl alcohol) Na...          Dong Z.Q.
# 17  Plant-derived nanostructures: types and applic...  Mohammadinejad R.
# 18  Novel inter-subunit contacts in barley stripe ...         Clare D.K.
# 19  Characterization of OsPM19L1 encoding an AWPM-...            Chen H.
# 20  Low Cost Tuberculosis Vaccine Antigens in Caps...       Lakshmi P.S.
# 21  Intracellular protein production in Trichoderm...      Mustalahti E.
# 22  Synthesis of 6H-SiC nanowires on bamboo leaves...             Zhu J.
# 23  Bioinspired self-cleaning surfaces with superh...       Nishimoto S.
# 24  Structural-functional insights of single and m...          Mishra M.
#
#     Year                                                URL
# 0   2023  https://api.elsevier.com/content/abstract/scop...
# 1   2023  https://api.elsevier.com/content/abstract/scop...
# 2   2023  https://api.elsevier.com/content/abstract/scop...
# 3   2023  https://api.elsevier.com/content/abstract/scop...
# 4   2023  https://api.elsevier.com/content/abstract/scop...
# 5   2019  https://api.elsevier.com/content/abstract/scop...
# 6   2019  https://api.elsevier.com/content/abstract/scop...
# 7   2019  https://api.elsevier.com/content/abstract/scop...
# 8   2019  https://api.elsevier.com/content/abstract/scop...
# 9   2019  https://api.elsevier.com/content/abstract/scop...
# 10  2018  https://api.elsevier.com/content/abstract/scop...
# 11  2018  https://api.elsevier.com/content/abstract/scop...
# 12  2018  https://api.elsevier.com/content/abstract/scop...
# 13  2018  https://api.elsevier.com/content/abstract/scop...
# 14  2018  https://api.elsevier.com/content/abstract/scop...
# 15  2015  https://api.elsevier.com/content/abstract/scop...
# 16  2015  https://api.elsevier.com/content/abstract/scop...
# 17  2015  https://api.elsevier.com/content/abstract/scop...
# 18  2015  https://api.elsevier.com/content/abstract/scop...
# 19  2015  https://api.elsevier.com/content/abstract/scop...
# 20  2013  https://api.elsevier.com/content/abstract/scop...
# 21  2013  https://api.elsevier.com/content/abstract/scop...
# 22  2013  https://api.elsevier.com/content/abstract/scop...
# 23  2013  https://api.elsevier.com/content/abstract/scop...
# 24  2013  https://api.elsevier.com/content/abstract/scop...
